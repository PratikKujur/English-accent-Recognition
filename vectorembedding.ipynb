# %%
import os
import librosa
import numpy as np
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import torch

# %%
# Initialize the Wav2Vec 2.0 processor and model
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-base-960h")
# Out:
# e:\Accent-Dataset\.venv\lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Base directory where .wav files are located
input_directory  = 'GLOBE\wavfiles'

# Output directory for embeddings
output_directory  = 'GLOBE\embeddings'
os.makedirs(output_directory , exist_ok=True)

# %%
# Determine the maximum length of audio sequences
max_length = 0
for accent_folder in os.listdir(input_directory):
    accent_path = os.path.join(input_directory, accent_folder)
    if os.path.isdir(accent_path):
        for audio_file in os.listdir(accent_path):
            if audio_file.endswith('.wav'):
                input_path = os.path.join(accent_path, audio_file)
                y, _ = librosa.load(input_path, sr=16000)
                max_length = max(max_length, len(y))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 9
#       7 if audio_file.endswith('.wav'):
#       8     input_path = os.path.join(accent_path, audio_file)
# ----> 9     y, _ = librosa.load(input_path, sr=16000)
#      10     max_length = max(max_length, len(y))
#
# File e:\Accent-Dataset\.venv\lib\site-packages\lazy_loader\__init__.py:83, in attach.<locals>.__getattr__(name)
#      81 submod_path = f"{package_name}.{attr_to_modules[name]}"
#      82 submod = importlib.import_module(submod_path)
# ---> 83 attr = getattr(submod, name)
#      85 # If the attribute lives in a file (module) with the same
#      86 # name as the attribute, ensure that the attribute and *not*
#      87 # the module is accessible on the package.
#      88 if name == attr_to_modules[name]:
#
# File e:\Accent-Dataset\.venv\lib\site-packages\lazy_loader\__init__.py:82, in attach.<locals>.__getattr__(name)
#      80 elif name in attr_to_modules:
#      81     submod_path = f"{package_name}.{attr_to_modules[name]}"
# ---> 82     submod = importlib.import_module(submod_path)
#      83     attr = getattr(submod, name)
#      85     # If the attribute lives in a file (module) with the same
#      86     # name as the attribute, ensure that the attribute and *not*
#      87     # the module is accessible on the package.
#
# File ~\AppData\Local\Programs\Python\Python38\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:671, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:783, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:219, in _call_with_frames_removed(f, *args, **kwds)
#
# File e:\Accent-Dataset\.venv\lib\site-packages\librosa\core\audio.py:14
#      12 import numpy as np
#      13 import scipy
# ---> 14 import scipy.signal
#      15 import soxr
#      16 import lazy_loader as lazy
#
# File e:\Accent-Dataset\.venv\lib\site-packages\scipy\signal\__init__.py:325
#     323 from ._filter_design import *
#     324 from ._fir_filter_design import *
# --> 325 from ._ltisys import *
#     326 from ._lti_conversion import *
#     327 from ._signaltools import *
#
# File e:\Accent-Dataset\.venv\lib\site-packages\scipy\signal\_ltisys.py:28
#      24 # np.linalg.qr fails on some tests with LinAlgError: zgeqrf returns -7
#      25 # use scipy's qr until this is solved
#      27 from scipy.linalg import qr as s_qr
# ---> 28 from scipy import integrate, interpolate, linalg
#      29 from scipy.interpolate import interp1d
#      30 from ._filter_design import (tf2zpk, zpk2tf, normalize, freqs, freqz, freqs_zpk,
#      31                             freqz_zpk)
#
# File <frozen importlib._bootstrap>:1039, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File e:\Accent-Dataset\.venv\lib\site-packages\scipy\__init__.py:230, in __getattr__(name)
#     228 def __getattr__(name):
#     229     if name in submodules:
# --> 230         return _importlib.import_module(f'scipy.{name}')
#     231     else:
#     232         try:
#
# File ~\AppData\Local\Programs\Python\Python38\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File e:\Accent-Dataset\.venv\lib\site-packages\scipy\integrate\__init__.py:94
#      92 from ._odepack_py import *
#      93 from ._quadpack_py import *
# ---> 94 from ._ode import *
#      95 from ._bvp import solve_bvp
#      96 from ._ivp import (solve_ivp, OdeSolution, DenseOutput,
#      97                    OdeSolver, RK23, RK45, DOP853, Radau, BDF, LSODA)
#
# File e:\Accent-Dataset\.venv\lib\site-packages\scipy\integrate\_ode.py:89
#      86 from numpy import asarray, array, zeros, isscalar, real, imag, vstack
#      88 from . import _vode
# ---> 89 from . import _dop
#      90 from . import _lsoda
#      93 _dop_int_dtype = _dop.types.intvar.dtype
#
# KeyboardInterrupt:

# %%
max_length=208002

# %%
# Iterate over each accent folder and process the .wav files
for accent_folder in os.listdir(input_directory):
    accent_path = os.path.join(input_directory, accent_folder)
    if os.path.isdir(accent_path):
        print(f"Processing accent folder: {accent_folder}")
        
        # Sanitize the accent folder name to remove or replace illegal characters
        sanitized_accent_folder = accent_folder.replace("/", "-")
        
        # Create output directory for the accent if it doesn't exist
        accent_output_dir = os.path.join(output_directory, sanitized_accent_folder)
        os.makedirs(accent_output_dir, exist_ok=True)
        
        # Iterate over each .wav file in the accent folder
        for audio_file in os.listdir(accent_path):
            if audio_file.endswith('.wav'):
                input_path = os.path.join(accent_path, audio_file)
                output_path = os.path.join(accent_output_dir, audio_file.replace('.wav', '.npy'))
                
                try:
                    # Load and resample audio file using librosa
                    waveform, sample_rate = librosa.load(input_path, sr=16000)  # Load with resampling to 16kHz
                    
                    # Pad the waveform to the maximum length
                    if len(waveform) < max_length:
                        waveform = np.pad(waveform, (0, max_length - len(waveform)), 'constant')
                    else:
                        waveform = waveform[:max_length]  # Truncate if it's longer
                    
                    # Reshape to the correct input format for Wav2Vec2
                    waveform = torch.tensor(waveform).unsqueeze(0)  # Shape: [1, sequence_length]
                    
                    # Process with Wav2Vec 2.0
                    inputs = processor(waveform, sampling_rate=16000, return_tensors="pt", padding=True)
                    
                    # Remove unnecessary extra dimension
                    inputs.input_values = inputs.input_values.squeeze(1)  # Shape: [batch_size, sequence_length]
                    
                    with torch.no_grad():
                        features = model(inputs.input_values).last_hidden_state
                    
                    # Convert to numpy and save
                    features_np = features.squeeze().cpu().numpy()
                    np.save(output_path, features_np)
                    
                    print(f"Processed {audio_file} and saved features to {output_path}")
                
                except Exception as e:
                    print(f"Error processing {audio_file}: {e}")
# Out:
# Processing accent folder: AGerman_English,Non_native_speaker
# Processed audio_train-00001-of-00108_3813.wav and saved features to GLOBE\embeddings\AGerman_English,Non_native_speaker\audio_train-00001-of-00108_3813.npy
# Processed audio_train-00001-of-00108_3814.wav and saved features to GLOBE\embeddings\AGerman_English,Non_native_speaker\audio_train-00001-of-00108_3814.npy
# Processed audio_train-00001-of-00108_3815.wav and saved features to GLOBE\embeddings\AGerman_English,Non_native_speaker\audio_train-00001-of-00108_3815.npy
# Processed audio_train-00001-of-00108_3816.wav and saved features to GLOBE\embeddings\AGerman_English,Non_native_speaker\audio_train-00001-of-00108_3816.npy
# Processed audio_train-00001-of-00108_3817.wav and saved features to GLOBE\embeddings\AGerman_English,Non_native_speaker\audio_train-00001-of-00108_3817.npy
# Processed audio_train-00001-of-00108_3818.wav and saved features to GLOBE\embeddings\AGerman_English,Non_native_speaker\audio_train-00001-of-00108_3818.npy
# Processed audio_train-00001-of-00108_3819.wav and saved features to GLOBE\embeddings\AGerman_English,Non_native_speaker\audio_train-00001-of-00108_3819.npy
# Processed audio_train-00001-of-00108_3820.wav and saved features to GLOBE\embeddings\AGerman_English,Non_native_speaker\audio_train-00001-of-00108_3820.npy
# Processed audio_train-00001-of-00108_3821.wav and saved features to GLOBE\embeddings\AGerman_English,Non_native_speaker\audio_train-00001-of-00108_3821.npy
# Processed audio_train-00001-of-00108_3822.wav and saved features to GLOBE\embeddings\AGerman_English,Non_native_speaker\audio_train-00001-of-00108_3822.npy
# Processed audio_train-00001-of-00108_3823.wav and saved features to GLOBE\embeddings\AGerman_English,Non_native_speaker\audio_train-00001-of-00108_
wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4646.npy
# Processed audio_train-00088-of-00108_4647.wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4647.npy
# Processed audio_train-00088-of-00108_4648.wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4648.npy
# Processed audio_train-00088-of-00108_4649.wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4649.npy
# Processed audio_train-00088-of-00108_4650.wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4650.npy
# Processed audio_train-00088-of-00108_4651.wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4651.npy
# Processed audio_train-00088-of-00108_4652.wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4652.npy
# Processed audio_train-00088-of-00108_4653.wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4653.npy
# Processed audio_train-00088-of-00108_4654.wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4654.npy
# Processed audio_train-00088-of-00108_4655.wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4655.npy
# Processed audio_train-00088-of-00108_4656.wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4656.npy
# Processed audio_train-00088-of-00108_4657.wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4657.npy
# Processed audio_train-00088-of-00108_4658.wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4658.npy
# Processed audio_train-00088-of-00108_4659.wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4659.npy
# Processed audio_train-00088-of-00108_4660.wav and saved features to GLOBE\embeddings\England_English,Canadian_English\audio_train-00088-of-00108_4660.npy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 40
#      37 inputs.input_values = inputs.input_values.squeeze(1)  # Shape: [batch_size, sequence_length]
#      39 with torch.no_grad():
# ---> 40     features = model(inputs.input_values).last_hidden_state
#      42 # Convert to numpy and save
#      43 features_np = features.squeeze().cpu().numpy()
#
# File e:\Accent-Dataset\.venv\lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File e:\Accent-Dataset\.venv\lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File e:\Accent-Dataset\.venv\lib\site-packages\transformers\models\wav2vec2\modeling_wav2vec2.py:1809, in Wav2Vec2Model.forward(self, input_values, attention_mask, mask_time_indices, output_attentions, output_hidden_states, return_dict)
#    1804 output_hidden_states = (
#    1805     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#    1806 )
#    1807 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1809 extract_features = self.feature_extractor(input_values)
#    1810 extract_features = extract_features.transpose(1, 2)
#    1812 if attention_mask is not None:
#    1813     # compute reduced attention_mask corresponding to feature vectors
#
# File e:\Accent-Dataset\.venv\lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File e:\Accent-Dataset\.venv\lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File e:\Accent-Dataset\.venv\lib\site-packages\transformers\models\wav2vec2\modeling_wav2vec2.py:463, in Wav2Vec2FeatureEncoder.forward(self, input_values)
#     458         hidden_states = self._gradient_checkpointing_func(
#     459             conv_layer.__call__,
#     460             hidden_states,
#     461         )
#     462     else:
# --> 463         hidden_states = conv_layer(hidden_states)
#     465 return hidden_states
#
# File e:\Accent-Dataset\.venv\lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File e:\Accent-Dataset\.venv\lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File e:\Accent-Dataset\.venv\lib\site-packages\transformers\models\wav2vec2\modeling_wav2vec2.py:310, in Wav2Vec2NoLayerNormConvLayer.forward(self, hidden_states)
#     309 def forward(self, hidden_states):
# --> 310     hidden_states = self.conv(hidden_states)
#     311     hidden_states = self.activation(hidden_states)
#     312     return hidden_states
#
# File e:\Accent-Dataset\.venv\lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File e:\Accent-Dataset\.venv\lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File e:\Accent-Dataset\.venv\lib\site-packages\torch\nn\modules\conv.py:308, in Conv1d.forward(self, input)
#     307 def forward(self, input: Tensor) -> Tensor:
# --> 308     return self._conv_forward(input, self.weight, self.bias)
#
# File e:\Accent-Dataset\.venv\lib\site-packages\torch\nn\modules\conv.py:304, in Conv1d._conv_forward(self, input, weight, bias)
#     300 if self.padding_mode != 'zeros':
#     301     return F.conv1d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     302                     weight, bias, self.stride,
#     303                     _single(0), self.dilation, self.groups)
# --> 304 return F.conv1d(input, weight, bias, self.stride,
#     305                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
